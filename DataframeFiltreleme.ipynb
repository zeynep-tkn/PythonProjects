# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynep-tkn/PythonProjects/blob/main/DataframeFiltreleme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from numpy.random import randn

# %%
df =pd.DataFrame(randn(4,4),['A','B','C','D'],["Column1","Column2","Column3","Column4"])
df
# Out:
#     Column1   Column2   Column3   Column4
# A -0.514220 -0.634683 -0.837209 -0.368630
# B -0.666109 -0.672371  0.014056 -0.728143
# C -1.292131  1.615230 -0.253205  0.524760
# D  1.274358  0.625765 -0.695920 -0.715695

# %%
df["Column1"] > -1
# Out:
# A     True
# B     True
# C    False
# D     True
# Name: Column1, dtype: bool

# %%
df[df["Column1"] > -1]
# Out:
#     Column1   Column2   Column3   Column4
# A -0.514220 -0.634683 -0.837209 -0.368630
# B -0.666109 -0.672371  0.014056 -0.728143
# D  1.274358  0.625765 -0.695920 -0.715695

# %% [markdown]
# Dataframe e Yeni Sütun Ekleme Yöntemleri

# %%
df['Column1'] =0
df
# Out:
#    Column1   Column2   Column3   Column4
# A        0 -0.634683 -0.837209 -0.368630
# B        0 -0.672371  0.014056 -0.728143
# C        0  1.615230 -0.253205  0.524760
# D        0  0.625765 -0.695920 -0.715695

# %%
df["Column5"]=randn(4)

# %%
df
# Out:
#    Column1   Column2   Column3   Column4   Column5
# A        0 -0.634683 -0.837209 -0.368630  0.688899
# B        0 -0.672371  0.014056 -0.728143 -0.003083
# C        0  1.615230 -0.253205  0.524760 -0.260938
# D        0  0.625765 -0.695920 -0.715695 -0.445258
