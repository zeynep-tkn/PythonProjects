# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynep-tkn/PythonProjects/blob/main/VYU_Imputing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VYU-5Imputing

# %%
pip install ucimlrepo

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-566dd39c1064> in <cell line: 6>()
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 6 from ydata_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ydata_profiling

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport # Artık bu içe aktarma işlemi çalışmalıdır
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.2 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=893f6ada8f921ce5275f7ea0168dd5cd38b4460c50efd44c5a8e7cde583f3ab8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from ucimlrepo import fetch_ucirepo
credit=fetch_ucirepo(id=27)
pd.concat([credit['data']['features'],credit['data']['targets']],axis=1).to_csv('credit.csv')

# %% [markdown]
# #Veriyi Hazırlama
# ## Boş değer ataması yapacağız

# %%
data=pd.read_csv('credit.csv')
profile=ProfileReport(data)
profile.to_file('credit.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'Function <code object pandas_auto_compute at 0x7a4f633dc450, file "/usr/local/lib/python3.10/dist-packages/ydata_profiling/model/pandas/correlations_pandas.py", line 167>')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.isna().sum()
# Out:
# Unnamed: 0     0
# A15            0
# A14           13
# A13            0
# A12            0
# A11            0
# A10            0
# A9             0
# A8             0
# A7             9
# A6             9
# A5             6
# A4             6
# A3             0
# A2            12
# A1            12
# A16            0
# dtype: int64

# %%
data
# Out:
#      Unnamed: 0  A15    A14 A13 A12  A11 A10 A9    A8  A7  A6 A5 A4      A3  \
# 0             0    0  202.0   g   f    1   t  t  1.25   v   w  g  u   0.000
# 1             1  560   43.0   g   f    6   t  t  3.04   h   q  g  u   4.460
# 2             2  824  280.0   g   f    0   f  t  1.50   h   q  g  u   0.500
# 3             3    3  100.0   g   t    5   t  t  3.75   v   w  g  u   1.540
# 4             4    0  120.0   s   f    0   f  t  1.71   v   w  g  u   5.625
# ..          ...  ...    ...  ..  ..  ...  .. ..   ...  ..  .. .. ..     ...
# 685         685    0  260.0   g   f    0   f  f  1.25   h   e  p  y  10.085
# 686         686  394  200.0   g   t    2   t  f  2.00   v   c  g  u   0.750
# 687         687    1  200.0   g   t    1   t  f  2.00  ff  ff  p  y  13.500
# 688         688  750  280.0   g   f    0   f  f  0.04   v  aa  g  u   0.205
# 689         689    0    0.0   g   t    0   f  f  8.29   h   c  g  u   3.375
#
#         A2 A1 A16
# 0    30.83  b   +
# ...

# %%
#veride düzenlemeler yapıp üzerinde çalışacak hale getirip saklayalım
data['A16'].replace(to_replace={'+':1,'-':0},inplace=True)
import random
random.seed(9001)
values=[random.randint(0,len(data)) for p in range(0,100)]
for var in ['A3','A8','A9','A10']:
  data.loc[values,var]=np.nan
data.info()
data.to_csv('creditApprovalUCI.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  690 non-null    int64
#  1   A15         690 non-null    int64
#  2   A14         677 non-null    float64
#  3   A13         690 non-null    object
#  4   A12         690 non-null    object
#  5   A11         690 non-null    int64
#  6   A10         598 non-null    object
#  7   A9          598 non-null    object
#  8   A8          598 non-null    float64
#  9   A7          681 non-null    object
#  10  A6          681 non-null    object
#  11  A5          684 non-null    object
#  12  A4          684 non-null    object
#  13  A3          598 non-null    float64
#  14  A2          678 non-null    float64
#  15  A1          678 non-null    object
#  16  A16         690 non-null    int64
# dtypes: float64(4), int64(4), object(9)
# memory usage: 91.8+ KB

# %%
data=pd.read_csv('creditApprovalUCI.csv')
data.isnull().mean()
# Out:
# Unnamed: 0    0.000000
# A15           0.000000
# A14           0.018841
# A13           0.000000
# A12           0.000000
# A11           0.000000
# A10           0.133333
# A9            0.133333
# A8            0.133333
# A7            0.013043
# A6            0.013043
# A5            0.008696
# A4            0.008696
# A3            0.133333
# A2            0.017391
# A1            0.017391
# A16           0.000000
# dtype: float64

# %%
data_clean=data.dropna()

# %%
print(f"Original dataset shape: {len(data)}")
print(f"Cleaned dataset shape: {len(data_clean)}")
# Out:
# Original dataset shape: 690
# Cleaned dataset shape: 564

# %% [markdown]
# Boş değerleri ortalama ve medyan değerleri ile doldurabiliriz

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from feature_engine.imputation import MeanMedianImputer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-88fa6762cbf8> in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.impute import SimpleImputer
# ----> 3 from feature_engine.imputation import MeanMedianImputer
#
# ModuleNotFoundError: No module named 'feature_engine'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install feature-engine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.1/357.1 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 84.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 86.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.2.2 which is incompatible.
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from feature_engine.imputation import MeanMedianImputer # Bu içe aktarma artık çalışmalıdır

# %%
x=data.drop('A16',axis=1)
y=data['A16']
X_train, X_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((483, 16), (207, 16), (483,), (207,))

# %%
X_train.isnull().mean()
# Out:
# Unnamed: 0    0.000000
# A15           0.000000
# A14           0.014493
# A13           0.000000
# A12           0.000000
# A11           0.000000
# A10           0.140787
# A9            0.140787
# A8            0.140787
# A7            0.008282
# A6            0.008282
# A5            0.008282
# A4            0.008282
# A3            0.140787
# A2            0.022774
# A1            0.008282
# dtype: float64

# %%
X_train.dtypes
# Out:
# Unnamed: 0      int64
# A15             int64
# A14           float64
# A13            object
# A12            object
# A11             int64
# A10            object
# A9             object
# A8            float64
# A7             object
# A6             object
# A5             object
# A4             object
# A3            float64
# A2            float64
# A1             object
# dtype: object

# %%
#Sayisal degiskenlerde doldurma islemlerine ilgileneceğiz. Manuel olarak her featur icin for dongusu ile yapalım
sayisal_degiskenler=X_train.select_dtypes(include=[np.float64, np.int64]).columns
sayisal_degiskenler

for degiskenler in sayisal_degiskenler:
  deger=X_train[degisken].median()
  X_train[degisken].fillna(deger,inplace=True)
  X_test[degisken].fillna(deger,inplace=True)
X_train.isnull().mean()
# Out:
# Index(['Unnamed: 0', 'A15', 'A14', 'A11', 'A8', 'A3', 'A2'], dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b59ab38bd918> in <cell line: 5>()
#       4
#       5 for degiskenler in sayisal_degiskenler:
# ----> 6   deger=X_train[degisken].median()
#       7   X_train[degisken].fillna(deger,inplace=True)
#       8   X_test[degisken].fillna(deger,inplace=True)
#
# NameError: name 'degisken' is not defined

# %%
sayisal_degiskenler=X_train.select_dtypes(include=[np.float64, np.int64]).columns
sayisal_degiskenler

for degisken in sayisal_degiskenler: # degiskenler was changed to degisken
  deger=X_train[degisken].median()
  X_train[degisken].fillna(deger,inplace=True)
  X_test[degisken].fillna(deger,inplace=True)
X_train.isnull().mean()
# Out:
# Index(['Unnamed: 0', 'A15', 'A14', 'A11', 'A8', 'A3', 'A2'], dtype='object')
# Unnamed: 0    0.000000
# A15           0.000000
# A14           0.000000
# A13           0.000000
# A12           0.000000
# A11           0.000000
# A10           0.140787
# A9            0.140787
# A8            0.000000
# A7            0.008282
# A6            0.008282
# A5            0.008282
# A4            0.008282
# A3            0.000000
# A2            0.000000
# A1            0.008282
# dtype: float64

# %%
X_train[sayisal_degiskenler]
# Out:
#      Unnamed: 0   A15    A14  A11      A8     A3     A2
# 596         596  4159  396.0    8   2.375  3.000  46.08
# 303         303     0  120.0    0   0.085  2.875  15.92
# 204         204  1187   50.0    1   0.085  2.125  36.33
# 351         351     0  100.0    0   0.000  0.585  22.17
# 118         118  1332  360.0    6  14.000  7.040  57.83
# ..          ...   ...    ...  ...     ...    ...    ...
# 359         359     0  160.0    0   0.000  4.710  36.75
# 192         192   600  510.0    0   2.500  0.960  41.75
# 629         629     5  220.0    0   1.665  0.665  19.58
# 559         559  2384  140.0    7   2.290  2.290  22.83
# 684         684     0  400.0    0   3.500  3.290  40.58
#
# [483 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
imputer=SimpleImputer(strategy='mediian')
imputer.fit(X_train[sayisal_degiskenler])
imputer.statistics_
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-25-024037aba9b3> in <cell line: 3>()
#       1 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
#       2 imputer=SimpleImputer(strategy='mediian')
# ----> 3 imputer.fit(X_train[sayisal_degiskenler])
#       4 imputer.statistics_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1143         check_is_fitted(self, "n_features_in_")
#    1144         return _check_feature_names_in(self, input_features)
# -> 1145
#    1146
#    1147 class ClassNamePrefixFeaturesOutMixin:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_params(self)
#     636         else:
#     637             if validate_separately:
# --> 638                 # We need this because some estimators validate X and y
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
imputer=SimpleImputer(strategy='median') # Correct the typo here
imputer.fit(X_train[sayisal_degiskenler])
imputer.statistics_
# Out:
# SimpleImputer(strategy='median')
# array([345.   ,   6.   , 160.   ,   0.   ,   1.   ,   2.75 ,  28.835])

# %%
X_train[sayisal_degiskenler]=imputer.transform(X_train[sayisal_degiskenler])
X_test[sayisal_degiskenler]=imputer.transform(X_test[sayisal_degiskenler])
X_train.isnull().mean()
# Out:
# Unnamed: 0    0.000000
# A15           0.000000
# A14           0.000000
# A13           0.000000
# A12           0.000000
# A11           0.000000
# A10           0.140787
# A9            0.140787
# A8            0.000000
# A7            0.008282
# A6            0.008282
# A5            0.008282
# A4            0.008282
# A3            0.000000
# A2            0.000000
# A1            0.008282
# dtype: float64
