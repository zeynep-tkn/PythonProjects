# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynep-tkn/PythonProjects/blob/main/PandasSerileri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Serileri: Etiketli verilerden oluşan tek boyutlu veri yapısıdır. Veriler değer, liste ya da python objesi olurken etiket değerine indis denilmektedir. Pythonda veri analizi için kullanılan yaygın bir kütüphanedir.

# %%
import numpy as np
import pandas as pd

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
labels_list=["Mustafa","Kemal","Murat","Kadir","Zeynep"]

# %%
data_list=[10,20,30,40,50]

# %%
pd.Series(data=data_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(data=data_list,index=labels_list)
# Out:
# Mustafa    10
# Kemal      20
# Murat      30
# Kadir      40
# Zeynep     50
# dtype: int64

# %%
ser2017= pd.Series(data=[5,10,14,20],index=["Buğday","Mantar","Elma","Portakal"])

# %%
ser2017
# Out:
# Buğday       5
# Mantar      10
# Elma        14
# Portakal    20
# dtype: int64

# %%
ser2018= pd.Series(data=[2,12,12,6],index=["Buğday","Mantar","Elma","Portakal"])

# %%
ser2018
# Out:
# Buğday       2
# Mantar      12
# Elma        12
# Portakal     6
# dtype: int64

# %% [markdown]
# #Dataframelerin Tanımlanmaları:
#  Satır ve sütuna sahip iki boyutlu veri yapılarıdır. İki boyutlu dizi ya da satır ve sütun şeklinde tablo olarak tanımlanabilir. Pandas Serileri bir boyutlu veri yapıları iken dataframeler iki boyutludur.

# %%
from numpy.random import randn

# %%
randn(3,3)
# Out:
# array([[-0.12862234,  0.86452556,  0.10502453],
#        [-0.96653128,  0.28228295, -0.83489136],
#        [-0.76218766,  0.26487154, -1.2934119 ]])

# %%
df=pd.DataFrame(data=randn(3,3),index=["A","B","C"],columns=["Column1","Column2","Column3"])

# %%
df
# Out:
#     Column1   Column2   Column3
# A -0.003720 -1.691981  1.336719
# B  0.316973  1.163797 -1.255842
# C -0.704100  1.219296  0.321733

# %%
df["Column2"]
# Out:
# A   -1.691981
# B    1.163797
# C    1.219296
# Name: Column2, dtype: float64

# %%
df.loc["A"]
# Out:
# Column1   -0.003720
# Column2   -1.691981
# Column3    1.336719
# Name: A, dtype: float64

# %%
df["Column4"]=0
df
# Out:
#     Column1   Column2   Column3  Column4
# A -0.003720 -1.691981  1.336719        0
# B  0.316973  1.163797 -1.255842        0
# C -0.704100  1.219296  0.321733        0

# %%
df["Column5"]=df["Column1"]+df["Column2"]+df["Column3"]+df["Column4"]
df
# Out:
#     Column1   Column2   Column3  Column4   Column5
# A -0.003720 -1.691981  1.336719        0 -0.358982
# B  0.316973  1.163797 -1.255842        0  0.224928
# C -0.704100  1.219296  0.321733        0  0.836930

# %% [markdown]
# Dataframeden Sütun Silme

# %%
df
# Out:
#     Column1   Column2   Column3  Column4   Column5
# A -0.003720 -1.691981  1.336719        0 -0.358982
# B  0.316973  1.163797 -1.255842        0  0.224928
# C -0.704100  1.219296  0.321733        0  0.836930

# %%
df.drop("Column4",axis=1)
# Out:
#     Column1   Column2   Column3   Column5
# A -0.003720 -1.691981  1.336719 -0.358982
# B  0.316973  1.163797 -1.255842  0.224928
# C -0.704100  1.219296  0.321733  0.836930

# %%
df.loc["A","Column2"]
# Out:
# -1.6919806362352274
